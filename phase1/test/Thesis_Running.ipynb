# %%
from google.colab import drive
drive.mount('/content/drive')
# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q "tensorflow" "tf-keras"
# !pip install -q "deepmd-kit[gpu,cu12,lmp,ipi,torch]" "dpdata"

# %%
import os
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'
os.environ["OMP_NUM_THREADS"] = "2"
os.environ["DP_INTRA_OP_PARALLELISM_THREADS"] = "2"
os.environ["DP_INTER_OP_PARALLELISM_THREADS"] = "1"

# %%
# %cd /content/drive/MyDrive/Thesis_Code/ThesisMaster
# Out:
# /content/drive/MyDrive/Thesis_Code/ThesisMaster

# %%
# !python3 phase1/start.py   -pred_only   -mp /content/drive/MyDrive/Thesis_Code/output_52_55_58_100_112/graph.pb   -p /content/drive/MyDrive/Thesis_Code/predict_79 -tf
# Out:
# 2025-09-13 10:21:09 - Import library...
# 2025-09-13 10:21:10 - Import library success
# 2025-09-13 10:21:10 - <update_process_ui>5</>
# 2025-09-13 10:21:10 -
# Server starting, hi!
#
# 2025-09-13 10:21:10 - Backend detected: TensorFlow
# 2025-09-13 10:21:10 - Model directory: /content/drive/MyDrive/Thesis_Code/output_52_55_58_100_112
# 2025-09-13 10:21:10 - Model file used: /content/drive/MyDrive/Thesis_Code/output_52_55_58_100_112/graph.pb
# 2025-09-13 10:21:10 - Running in predict-only mode...
# 2025-09-13 10:21:10 - <update_process_ui>60</>
# 2025-09-13 10:21:10 - <update_process_ui>95</>
# 2025-09-13 10:21:11.761627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
