# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content

# %%
# !pip install -q deepmd-kit[lmp,ipi] dpdata
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.6/487.6 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 33.7 MB/s eta 0:00:00
# ...

# %%
# %cd /content/gdrive/MyDrive/Ths/Code_ThS/
# Out:
# /content/gdrive/MyDrive/Ths/Code_ThS

# %%
# !python3 phase1/start.py -i /content/gdrive/MyDrive/Ths/Code_ThS/data_test_in -o /content/gdrive/MyDrive/Ths/Code_ThS/data_test_out
# Out:
# 2024-10-23 14:32:41 - Import library...
# 2024-10-23 14:32:42 - NumExpr defaulting to 2 threads.
# 2024-10-23 14:32:42 - Import library success
# 2024-10-23 14:32:42 -
# Server starting, hi!
#
# 2024-10-23 14:33:00 -
# ***Step 1 in phase 1 run successfully!
#
# 2024-10-23 14:33:00 -
# ***Step 2 in phase 1 run successfully!
#
# Figure(640x480)
# 2024-10-23 14:41:42 -
# ***Step 3 in phase 1 run successfully!
#
# 2024-10-23 14:43:55.773566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 14:43:55.817729: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %cd /content/gdrive/MyDrive/Ths/Code_ThS/scripts
# Out:
# /content/gdrive/MyDrive/Ths/Code_ThS/scripts

# %%
# !apt-get install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 384 kB of archives.
# After this operation, 1,367 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dos2unix amd64 7.4.2-2 [384 kB]
# Fetched 384 kB in 1s (606 kB/s)
# Selecting previously unselected package dos2unix.
# (Reading database ... 123622 files and directories currently installed.)
# Preparing to unpack .../dos2unix_7.4.2-2_amd64.deb ...
# Unpacking dos2unix (7.4.2-2) ...
# Setting up dos2unix (7.4.2-2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !dos2unix ./run_script.sh
# Out:
# dos2unix: converting file ./run_script.sh to Unix format...

# %%
# !chmod +x ./run_script.sh

# %%
# !./run_script.sh -i /content/gdrive/MyDrive/Ths/Code_ThS/data_test_in -o /content/gdrive/MyDrive/Ths/Code_ThS/data_test_out
# Out:
# 2024-10-23 14:54:15 - Import library...
# 2024-10-23 14:54:17 - NumExpr defaulting to 2 threads.
# 2024-10-23 14:54:17 - Import library success
# 2024-10-23 14:54:17 -
# Server starting, hi!
#
# 2024-10-23 14:54:17 -
# ***Step 1/4 in phase 1 on running!
#
# 2024-10-23 14:54:35 -
# ***Step 1/4 in phase 1 run successfully!
#
# 2024-10-23 14:54:35 -
# ***Step 2/4 in phase 1 on running!
#
# 2024-10-23 14:54:35 -
# ***Step 2/4 in phase 1 run successfully!
#
# 2024-10-23 14:54:35 -
# ***Step 3/4 in phase 1 on running!
#
# Figure(640x480)
# 2024-10-23 15:02:53 -
# ***Step 3/4 in phase 1 run successfully!
#
# 2024-10-23 15:02:53 -
# ***Step 4/4 in phase 1 on running!
#
# 2024-10-23 15:05:11.332647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
