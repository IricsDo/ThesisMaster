# %% [markdown]
# <a href="https://colab.research.google.com/github/IricsDo/ThesisMaster/blob/main/test_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -q deepmd-kit[lmp,ipi] dpdata
# !apt-get install dos2unix
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.6/487.6 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 33.2 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 384 kB of archives.
# After this operation, 1,367 kB of additional disk space will be used.
# ...

# %%
# !ssh-keygen -t rsa -b 4096
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:wxfTFmKdhXXYAE+65W9u21xYuxR8WWbHEoeuMu6VbFc root@43393c7694fd
# The key's randomart image is:
# +---[RSA 4096]----+
# |          o.o**=o|
# |         . o+=o=.|
# |          o +.+ *|
# |       .   + +o++|
# |        S . ...+E|
# |         oo... =+|
# |         . o= oo+|
# |          .o ..+=|
# |         ..    +=|
# +----[SHA256]-----+

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-44e29decf

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@43393c7694fd

# %%
# !ssh -T git@github.com
# Out:
# Hi IricsDo! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git config --global user.email "iric.life1407@gmail.com"
# !git config --global user.name "Iris on Colab"

# %%
# !git clone git@github.com:IricsDo/ThesisMaster.git
# Out:
# Cloning into 'ThesisMaster'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 282 (delta 95), reused 248 (delta 67), pack-reused 0 (from 0)
# Receiving objects: 100% (282/282), 10.42 MiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (95/95), done.

# %%
# %cd /content/ThesisMaster
# Out:
# /content/ThesisMaster

# %%
# !python3 phase1/start.py -i "/content/ThesisMaster/data_test_in" -o "/content/ThesisMaster/data_test_out"
# Out:
# 2024-11-01 17:01:51 - Import library...
# 2024-11-01 17:01:52 - NumExpr defaulting to 2 threads.
# 2024-11-01 17:01:52 - Import library success
# 2024-11-01 17:01:52 -
# Server starting, hi!
#
# 2024-11-01 17:01:52 - Error: Input folder '/content/ThesisMaster/data_test_in' does not exist.

# %%
# !dos2unix ./run_script.sh
# Out:
# dos2unix: converting file ./run_script.sh to Unix format...

# %%
# !chmod +x ./run_script.sh

# %%
# !./run_script.sh -i /content/gdrive/MyDrive/Ths/Code_ThS/data_test_in -o /content/gdrive/MyDrive/Ths/Code_ThS/data_test_out
# Out:
# 2024-10-23 14:54:15 - Import library...
# 2024-10-23 14:54:17 - NumExpr defaulting to 2 threads.
# 2024-10-23 14:54:17 - Import library success
# 2024-10-23 14:54:17 -
# Server starting, hi!
#
# 2024-10-23 14:54:17 -
# ***Step 1/4 in phase 1 on running!
#
# 2024-10-23 14:54:35 -
# ***Step 1/4 in phase 1 run successfully!
#
# 2024-10-23 14:54:35 -
# ***Step 2/4 in phase 1 on running!
#
# 2024-10-23 14:54:35 -
# ***Step 2/4 in phase 1 run successfully!
#
# 2024-10-23 14:54:35 -
# ***Step 3/4 in phase 1 on running!
#
# Figure(640x480)
# 2024-10-23 15:02:53 -
# ***Step 3/4 in phase 1 run successfully!
#
# 2024-10-23 15:02:53 -
# ***Step 4/4 in phase 1 on running!
#
# 2024-10-23 15:05:11.332647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
